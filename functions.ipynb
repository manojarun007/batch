# %%
for i in range(10):
    print "str",i
# Out:
# str 0
# str 1
# str 2
# str 3
# str 4
# str 5
# str 6
# str 7
# str 8
# str 9

# %%
print "program started"
def fun():
    print "this is st1 in fun"
    print "this is st2 in fun"
    print "this is st3 in fun"
    print "this is st4 in fun"
print "statements after function"
print "other statements in program"
print "program ended"
# Out:
# program started
# statements after function
# other statements in program
# program ended

# %%
print "program started"
def fun():
    print "this is st1 in fun"
    print "this is st2 in fun"
    print "this is st3 in fun"
    print "this is st4 in fun"
print "statements after function"
fun()
print "other statements in program"
print "program ended"
# Out:
# program started
# statements after function
# this is st1 in fun
# this is st2 in fun
# this is st3 in fun
# this is st4 in fun
# other statements in program
# program ended

# %%
print "program started"
def fun():
    print "this is st1 in fun
    print "this is st2 in fun"
    print "this is st3 in fun"
    print "this is st4 in fun"
print "statements after function"
print "other statements in program"
print "program ended"
# Out:
#   File "<ipython-input-5-812d7c0ce8c2>", line 3
#     print "this is st1 in fun
#                             ^
# SyntaxError: EOL while scanning string literal

# %%
print "program started"
def fun():
    print 1/0
    print "this is st1 in fun"
    print "this is st2 in fun"
    print "this is st3 in fun"
    print "this is st4 in fun"
print "statements after function"

print "other statements in program"
print "program ended"
# Out:
# program started
# statements after function
# other statements in program
# program ended

# %%
print "program started"
def fun():
    print "this is fun"
print "statements after function"
fun()
print "other statements in program"
print "program ended"
fun()
# Out:
# program started
# statements after function
# this is fun
# other statements in program
# program ended
# this is fun

# %%
for i in range(2):
    print "this is loop"
print "program started"
def fun():
    print "this is fun"
print "statements after function"
fun()
print "other statements in program"
print "program ended"
fun()
# Out:
# this is loop
# this is loop
# program started
# statements after function
# this is fun
# other statements in program
# program ended
# this is fun

# %%
print "program started"
def fun():
    print "this is fun"
print "statements after function def"
fun()
print "program ended"
# Out:
# program started
# statements after function def
# this is fun
# program ended

# %%
print "program started"
def fun(a,b):
    print "this is fun"
print "statements after function def"
fun()
print "program ended"
# Out:
# program started
# statements after function def
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-be9536521c40> in <module>()
#       3     print "this is fun"
#       4 print "statements after function def"
# ----> 5 fun()
#       6 print "program ended"
#
# TypeError: fun() takes exactly 2 arguments (0 given)

# %%
print "program started"
def fun(a,b):
    print "this is fun"
print "statements after function def"
fun(10)
print "program ended"
# Out:
# program started
# statements after function def
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f44b992202d1> in <module>()
#       3     print "this is fun"
#       4 print "statements after function def"
# ----> 5 fun(10)
#       6 print "program ended"
#
# TypeError: fun() takes exactly 2 arguments (1 given)

# %%
print "program started"
def fun(a,b):
    print "this is fun"
print "statements after function def"
fun(10,20)
print "program ended"
# Out:
# program started
# statements after function def
# this is fun
# program ended

# %%
print "program started"
def fun(a,b):
    print "a=",a,"b=",b
    print a+b
    print a-b
    print a*b
    print a/b
    print a%b
print "statements after function def"
fun(10,20)
print "program ended"
# Out:
# program started
# statements after function def
# a= 10 b= 20
# 30
# -10
# 200
# 0
# 10
# program ended

# %%
print "program started"
def fun(a,b):
    print "*"*20
    print "a=",a,"b=",b
    print a+b
    print a-b
    print a*b
    print a/b
    print a%b
print "statements after function def"
fun(10,20)
print "program ended"
fun(100,200)
fun(1000,2000)
fun(23.45,567)
fun(23.45,67.89)
# Out:
# program started
# statements after function def
# ********************
# a= 10 b= 20
# 30
# -10
# 200
# 0
# 10
# program ended
# ********************
# a= 100 b= 200
# 300
# -100
# 20000
# 0
# 100
# ********************
# a= 1000 b= 2000
# 3000
# -1000
# 2000000
# 0
# 1000
# ********************
# a= 23.45 b= 567
# 590.45
# -543.55
# 13296.15
# 0.0413580246914
# 23.45
# ********************
# a= 23.45 b= 67.89
# 91.34
# -44.44
# 1592.0205
# 0.34541169539
# 23.45

# %%
def fun(a,b):
    print "*"*20
    print "a=",a,"b=",b
    print a+b
    print a-b
    print a*b
    print a/b
    print a%b
c=int(raw_input("Enter a value:"))
d=int(raw_input("Enter b value:"))
fun(c,d)
# Out:
# Enter a value:10
# Enter b value:20
# ********************
# a= 10 b= 20
# 30
# -10
# 200
# 0
# 10

# %%
def fun(a,b):
    print "*"*20
    print "a=",a,"b=",b
    print a+b

fun(10,20)
# Out:
# ********************
# a= 10 b= 20
# 30

# %%
# 2,5
def fun(a,b):
    print "*"*20
    print "a=",a,"b=",b
    print a+b

fun(10,20)
fun(10,20,30)
fun(10,20,30,40)
fun(10,20,30,40,50)
# Out:
# ********************
# a= 10 b= 20
# 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b4f2867c3812> in <module>()
#       6
#       7 fun(10,20)
# ----> 8 fun(10,20,30)
#       9 fun(10,20,30,40)
#      10 fun(10,20,30,40,50)
#
# TypeError: fun() takes exactly 2 arguments (3 given)

# %%
# 2,5
def fun(a,b,c,d,e):
    print "*"*20
    print "a=",a,"b=",b
    print a+b

fun(10,20)
fun(10,20,30)
fun(10,20,30,40)
fun(10,20,30,40,50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6a7d0fa175bc> in <module>()
#       5     print a+b
#       6
# ----> 7 fun(10,20)
#       8 fun(10,20,30)
#       9 fun(10,20,30,40)
#
# TypeError: fun() takes exactly 5 arguments (2 given)

# %%
# 2,5
# default argument/parameters
def fun(a,b,c=0,d=0,e=0):
    #doc string
    """
    a,b are mandatory params
    c,d,e are optional params
    a,b,c,d,e: type: int
    return: 
    desc: take 2 to 5 numbers and adds the numbers
    """
    print "*"*20
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20)
fun(10,20,30)
fun(10,20,30,40)
fun(10,20,30,40,50)
# Out:
# ********************
# a= 10 b= 20 c= 0 d= 0 e= 0
# 30
# ********************
# a= 10 b= 20 c= 30 d= 0 e= 0
# 60
# ********************
# a= 10 b= 20 c= 30 d= 40 e= 0
# 100
# ********************
# a= 10 b= 20 c= 30 d= 40 e= 50
# 150

# %%
# 2,5
# default argument/parameters
def fun(a,b,c=0,d=0,e=0):
    #doc string
    """
    a,b are mandatory params
    c,d,e are optional params
    a,b,c,d,e: type: int
    return: 
    desc: take 2 to 5 numbers and adds the numbers
    """
    print "*"*20
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-3e10a8a937ce> in <module>()
#      14     print a+b+c+d+e
#      15
# ---> 16 fun(10)
#
# TypeError: fun() takes at least 2 arguments (1 given)

# %%
# 2,5
# default argument/parameters
def fun(a,b,c=0,d=0,e=0):
    #doc string
    """
    a,b are mandatory params
    c,d,e are optional params
    a,b,c,d,e: type: int
    return: 
    desc: take 2 to 5 numbers and adds the numbers
    """
    print "*"*20
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20,30,40,50,60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-87684e889ed2> in <module>()
#      14     print a+b+c+d+e
#      15
# ---> 16 fun(10,20,30,40,50,60)
#
# TypeError: fun() takes at most 5 arguments (6 given)

# %%
# default argument/parameters
def fun(a=0,b=0,c=0,d=0,e=0):
    #doc string
    """
    a,b,c,d,e: type: int
    return: 
    desc: take 2 to 5 numbers and adds the numbers
    """
    print "*"*20
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun()
# Out:
# ********************
# a= 0 b= 0 c= 0 d= 0 e= 0
# 0

# %%
def fun(a,b=[]):
    print a+b
fun(10,20)
# Out:
# 30

# %%
def fun(a,b=[]):
    print a+b
fun(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-39e191888340> in <module>()
#       1 def fun(a,b=[]):
#       2     print a+b
# ----> 3 fun(10)
#
# <ipython-input-26-39e191888340> in fun(a, b)
#       1 def fun(a,b=[]):
# ----> 2     print a+b
#       3 fun(10)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
import pandas as pd

# %%
pd.read_csv?

# %%
def fun(a,b=[]):
    print a+b
fun(10,20)
# Out:
# 30

# %%
def fun(a=0,b=0,c=0,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun()
# Out:
# a= 0 b= 0 c= 0 d= 0 e= 0
# 0

# %%
def fun(a,b=0,c=0,d=0,e=0,f):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(a=10,f=20)
# Out:
#   File "<ipython-input-31-c31b0b0179e5>", line 1
#     def fun(a,b=0,c=0,d=0,e=0,f):
# SyntaxError: non-default argument follows default argument

# %%
def fun(a,b=0,c=0,d=0,e=0,f):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20)
# Out:
#   File "<ipython-input-32-0c597d7a1db4>", line 1
#     def fun(a,b=0,c=0,d=0,e=0,f):
# SyntaxError: non-default argument follows default argument

# %%
def fun(a,b=0,c=0,d=0,e=0,f):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20,,,,30)
# Out:
#   File "<ipython-input-35-cf57e69c7040>", line 5
#     fun(10,20,,,,30)
#               ^
# SyntaxError: invalid syntax

# %%
def fun(a,b=0,c=0,d=0,e=0,f):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20,"","","",30)
# Out:
#   File "<ipython-input-36-e62635a25418>", line 1
#     def fun(a,b=0,c=0,d=0,e=0,f):
# SyntaxError: non-default argument follows default argument

# %%
def fun(a,f,b=0,c=0,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20,"","","",30)
# Out:
# a= 10 b=  c=  d=  e= 30
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-b9e1f4b55218> in <module>()
#       3     print a+b+c+d+e
#       4
# ----> 5 fun(10,20,"","","",30)
#
# <ipython-input-37-b9e1f4b55218> in fun(a, f, b, c, d, e)
#       1 def fun(a,f,b=0,c=0,d=0,e=0):
#       2     print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
# ----> 3     print a+b+c+d+e
#       4
#       5 fun(10,20,"","","",30)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
def fun(a,b,c=0,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e

fun(10,20)
# Out:
# a= 10 b= 20 c= 0 d= 0 e= 0
# 30

# %%
def fun(a,b,c=0,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
#100
fun(10,20,100)
# Out:
# a= 10 b= 20 c= 100 d= 0 e= 0
# 130

# %%
def fun(a,b,c=0,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
#100
fun(10,20,0,0,100)
# Out:
# a= 10 b= 20 c= 0 d= 0 e= 100
# 130

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
#100
fun(10,20,10,0,100)
# Out:
# a= 10 b= 20 c= 10 d= 0 e= 100
# 140

# %%
pd.read_csv?

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(10,20,e=100)
# Out:
# a= 10 b= 20 c= 10 d= 0 e= 100
# 140

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(a=10,b=20,e=100)
# Out:
# a= 10 b= 20 c= 10 d= 0 e= 100
# 140

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(b=10,a=20,e=100)
# Out:
# a= 20 b= 10 c= 10 d= 0 e= 100
# 140

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(b=10,c=20,e=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-dae92ee0a9d9> in <module>()
#       3     print a+b+c+d+e
#       4 # keyword argument
# ----> 5 fun(b=10,c=20,e=100)
#
# TypeError: fun() takes at least 2 arguments (3 given)

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(b=10,c=20,e=100,a=400)
# Out:
# a= 400 b= 10 c= 20 d= 0 e= 100
# 530

# %%
def fun(a,b,c=10,d=0,e=0):
    print "a=",a,"b=",b,"c=",c,"d=",d,"e=",e
    print a+b+c+d+e
# keyword argument
fun(b=10,c=20,e=100,a=400)
print "out side fun e=",e
# Out:
# a= 400 b= 10 c= 20 d= 0 e= 100
# 530
# out side fun e=
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-05524f01a2a0> in <module>()
#       4 # keyword argument
#       5 fun(b=10,c=20,e=100,a=400)
# ----> 6 print "out side fun e=",e
#
# NameError: name 'e' is not defined

# %%
if True:
    a=100
print a
# Out:
#  100

# %%
def fun():
    x=1000
fun()
print x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-f488cc2a99d6> in <module>()
#       2     x=1000
#       3 fun()
# ----> 4 print x
#
# NameError: name 'x' is not defined
