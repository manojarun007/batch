# %%
a=10
b=20
c=a+b

# %%
f=open("data.csv","w")

# %%
f.write("some data")

# %%
f.close()

# %%
pwd
# Out:
# u'/home/khyaathi-python/pythonexamples/batch48'

# %%
f=open("data.csv","W")
f.write("some data")
f.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9afdf3d16d09> in <module>()
# ----> 1 f=open("data.csv","W")
#       2 f.write("some data")
#       3 f.close()
#
# ValueError: mode string must begin with one of 'r', 'w', 'a' or 'U', not 'W'

# %%
f=open("data.csv","w")
f.write("some data")
f.close()

# %%
f=open("data.csv","w")

# %%
f=open("data.csv","w")
f.write("some data")
f.close()
f.write("some more data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ec48a57ff3b0> in <module>()
#       2 f.write("some data")
#       3 f.close()
# ----> 4 f.write("some more data")
#
# ValueError: I/O operation on closed file

# %%
f=open("data.csv","w")
f.write("some data")
f.flush()
f.write("some more data")

# %%
f.close()

# %%
f=open("data.csv","w")
try:
    f.write("id,name,phone\n")
    p_id=raw_input("Enter an id:")
    p_name=raw_input("Enter name:")
    p_phone=raw_input("Enter phone:")
    row = "%s,%s,%s"%(p_id,p_name,p_phone)
    f.write(row)
except Exception as err:
    print err
finally:
    f.close()
# Out:
# Enter an id:23
# Enter name:ashok kumar
# Enter phone:9676622024

# %%
f=open("data.csv","w")
try:
    f.write("id,name,phone\n")
    p_id=raw_input("Enter an id:")
    p_name=raw_input("Enter name:")
    p_phone=raw_input("Enter phone:")
    row = "%s,%s,%s"%(p_id,p_name,p_phone)
    f.write(row)
except Exception as err:
    print err
finally:
    f.close()
# Out:
# Enter an id:12
# Enter name:anil
# Enter phone:9676622023

# %%
f=open("data.csv","r")

# %%
f=open("data2.csv","r")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-ed19d2a6c5c9> in <module>()
# ----> 1 f=open("data2.csv","r")
#
# IOError: [Errno 2] No such file or directory: 'data2.csv'

# %%
try:
    f=open("data2.csv","r")
except IOError as err:
    print err
finally:
    f.close()
# Out:
# [Errno 2] No such file or directory: 'data2.csv'

# %%
try:
    f=open("data2.csv","r")
    data=f.read()
    print data
    print type(data)
except IOError as err:
    print err
finally:
    f.close()
# Out:
# [Errno 2] No such file or directory: 'data2.csv'

# %%
try:
    f=open("data.csv","r")
    data=f.read()
    print data
    print type(data)
except IOError as err:
    print err
finally:
    f.close()
# Out:
# id,name,phone
# 12,anil,9676622023
# <type 'str'>

# %%
try:
    f=open("data.csv","r")
    data=f.read()
    print data
    print type(data)
    f.write("sdfsdgs")
except IOError as err:
    print err
finally:
    f.close()
# Out:
# id,name,phone
# 12,anil,9676622023
# <type 'str'>
# File not open for writing

# %%
names=["manoj","giri","manasa","mahesh","jay","vedha","sai","samba","dhana"]
import random
f=open("data.csv","w")
f.write("id,name\n")
for i in range(3):
    f.write("%s,%s\n"%(i,random.choice(names)))
f.close()

# %%
names=["manoj","giri","manasa","mahesh","jay","vedha","sai","samba","dhana"]
import random
f=open("data.csv","w")
f.write("id,name\n")
for i in range(3000):
    f.write("%s,%s\n"%(i,random.choice(names)))
    f.flush()
f.close()

# %%
# pyhon is a pure object oriented programing language
s="pyhon is a pure object oriented programing language"
print s.count(" ")
# Out:
# 7

# %%
# pyhon is a pure object oriented programing language
s="pyhon is a pure object oriented programing language"
print s.count(" ")+1
# Out:
# 8

# %%
# pyhon is a pure object oriented programing language
s="pyhon is a pure object oriented programing language"
print s.count(" ")+1
print len(s)
# Out:
# 8
# 51

# %%
# pyhon is a pure object oriented programing language
s="pyhon is a pure object oriented programing language"
print s.count(" ")+1
print len(s)-s.count(" ")
# Out:
# 8
# 44

# %%
try:
    f=open("data.csv","r")
    rows = f.readlines()
    print rows
except IOError as err:
    print err
finally:
    f.close()
# Out:
# ['id,name\n', '0,giri\n', '1,mahesh\n', '2,mahesh\n', '3,dhana\n', '4,manasa\n', '5,vedha\n', '6,giri\n', '7,giri\n', '8,samba\n', '9,vedha\n', '10,dhana\n', '11,jay\n', '12,sai\n', '13,samba\n', '14,giri\n', '15,mahesh\n', '16,dhana\n', '17,giri\n', '18,mahesh\n', '19,manoj\n', '20,vedha\n', '21,manasa\n', '22,vedha\n', '23,giri\n', '24,jay\n', '25,sai\n', '26,mahesh\n', '27,vedha\n', '28,manasa\n', '29,jay\n', '30,mahesh\n', '31,manasa\n', '32,manoj\n', '33,dhana\n', '34,manasa\n', '35,manoj\n', '36,giri\n', '37,samba\n', '38,dhana\n', '39,manasa\n', '40,mahesh\n', '41,jay\n', '42,samba\n', '43,jay\n', '44,mahesh\n', '45,jay\n', '46,samba\n', '47,dhana\n', '48,manasa\n', '49,samba\n', '50,giri\n', '51,samba\n', '52,dhana\n', '53,dhana\n', '54,samba\n', '55,sai\n', '56,giri\n', '57,jay\n', '58,samba\n', '59,jay\n', '60,samba\n', '61,jay\n', '62,manoj\n', '63,dhana\n', '64,mahesh\n', '65,giri\n', '66,dhana\n', '67,vedha\n', '68,sai\n', '69,samba\n', '70,mahesh\n', '71,vedha\n', '72,v
# ...

# %%
try:
    f=open("data.csv","r")
    print f.readline()
    print f.readline()
except IOError as err:
    print err
finally:
    f.close()
# Out:
# id,name
#
# 0,giri

# %%
f.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-c4ba08551b5f> in <module>()
# ----> 1 f.readline()
#
# ValueError: I/O operation on closed file

# %%
f=open("data.csv")
data=f.read()
print data
# Out:
# id,name
# 0,giri
# 1,mahesh
# 2,mahesh
# 3,dhana
# 4,manasa
# 5,vedha
# 6,giri
# 7,giri
# 8,samba
# 9,vedha
# 10,dhana
# 11,jay
# 12,sai
# 13,samba
# 14,giri
# 15,mahesh
# 16,dhana
# 17,giri
# 18,mahesh
# 19,manoj
# 20,vedha
# 21,manasa
# 22,vedha
# 23,giri
# 24,jay
# 25,sai
# 26,mahesh
# 27,vedha
# 28,manasa
# 29,jay
# 30,mahesh
# 31,manasa
# 32,manoj
# 33,dhana
# 34,manasa
# 35,manoj
# 36,giri
# 37,samba
# 38,dhana
# 39,manasa
# 40,mahesh
# 41,jay
# 42,samba
# 43,jay
# 44,mahesh
# 45,jay
# 46,samba
# 47,dhana
# 48,manasa
# 49,samba
# 50,giri
# 51,samba
# 52,dhana
# 53,dhana
# 54,samba
# 55,sai
# 56,giri
# 57,jay
# 58,samba
# 59,jay
# 60,samba
# 61,jay
# 62,manoj
# 63,dhana
# 64,mahesh
# 65,giri
# 66,dhana
# 67,vedha
# 68,sai
# 69,samba
# 70,mahesh
# 71,vedha
# 72,vedha
# 73,mahesh
# 74,manasa
# 75,manoj
# 76,samba
# 77,dhana
# 78,vedha
# 79,giri
# 80,mahesh
# 81,sai
# 82,sai
# 83,manasa
# 84,giri
# 85,sai
# 86,manasa
# 87,samba
# 88,sai
# 89,samba
# 90,giri
# 91,giri
# 92,manoj
# ...

# %%
f=open("data.csv")
data=f.read()
#print data
data1=f.read()
print data1

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
for row in rows:
    print row.split(",")[0]
    break
# Out:
# enter an id to delete:23
# id

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
for row in rows:
    if row.split(",")[0] == p_id:
        print row
        break
# Out:
# enter an id to delete:23
# 23,giri

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
for row in rows:
    if row.split(",")[0] == p_id:
        rows.remove(row)
        break
print rows
# Out:
# enter an id to delete:2
# ...

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
for row in rows:
    if row.split(",")[0] == p_id:
        rows.remove(row)
        break
f.close()
f=open("data.csv","w")
f.writelines(rows)
f.close()
# Out:
# enter an id to delete:23

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
for row in rows:
    if row.split(",")[0] == p_id:
        rows.remove(row)
        break
f.close()
f=open("data.csv","w")
f.writelines(rows)
f.close()
# Out:
# enter an id to delete:2

# %%
f=open("data.csv")
p_id=raw_input("enter an id to delete:")
rows=f.readlines()
index = 0
for row in rows:
    if row.split(",")[0] == p_id:
        print row
        p_id, p_name = row.split(",")
        new_name=raw_input("Enter name:")
        new_row="%s,%s\n"%(p_id, new_name)
        rows[index]=new_row
        break
    index = index+1
f.close()
f=open("data.csv","w")
f.writelines(rows)
f.close()
# Out:
# enter an id to delete:3
# Enter name:ashok
